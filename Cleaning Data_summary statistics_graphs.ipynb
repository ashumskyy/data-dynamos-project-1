# %%
# Importing dependencies
from matplotlib import pyplot as plt, ticker as mticker
import pandas as pd
import numpy as np
from scipy.stats import linregress

# %%
# Reading .csv files
adj_net_national_income_csv = pd.read_csv('Resources/Adj_net_national_income_world_bank_20_years.csv')
GDP_csv = pd.read_csv('Resources/GDP_world_bank_20_years.csv')
Inflation_consumer_prices_csv = pd.read_csv('Resources/Inflation_consumer_prices_world_bank_20_years.csv')

# %%
# Creating data frames
adj_net_national_income_df = pd.DataFrame(adj_net_national_income_csv)
gdp_df = pd.DataFrame(GDP_csv)
inflation_consumer_prices_df = pd.DataFrame(Inflation_consumer_prices_csv)

# %%
#  ---------------------------
# Adjusted net national income for 2002-2019

# %%
# Dropping not nedded coumns
adj_net_nat_income_df = adj_net_national_income_df.drop(columns=['Series Code', 'Series Name', '2020 [YR2020]', '2021 [YR2021]'])

# %%
# Renaming the columns
adj_net_nat_income_renamed = adj_net_nat_income_df.rename(columns={
    '2002 [YR2002]' : '2002',
    '2003 [YR2003]' : '2003',
    '2004 [YR2004]' : '2004',
    '2005 [YR2005]' : '2005',
    '2006 [YR2006]' : '2006',
    '2007 [YR2007]' : '2007',
    '2008 [YR2008]' : '2008',
    '2009 [YR2009]' : '2009',
    '2010 [YR2010]' : '2010',
    '2011 [YR2011]' : '2011',
    '2012 [YR2012]' : '2012',
    '2013 [YR2013]' : '2013',
    '2014 [YR2014]' : '2014',
    '2015 [YR2015]' : '2015',
    '2016 [YR2016]' : '2016',
    '2017 [YR2017]' : '2017',
    '2018 [YR2018]' : '2018',
    '2019 [YR2019]' : '2019'  
})

# %%
# Replacing all empty values with NaN
adj_net_nat_income_droped = adj_net_nat_income_renamed.replace('..', np.nan)

# Dropping all NaN
adj_net_nat_income_final = adj_net_nat_income_droped.dropna(axis=0)

# %%
for i, col in enumerate(adj_net_nat_income_final.columns):
    if i >= 2 and adj_net_nat_income_final[col].dtype == 'object':
        adj_net_nat_income_final[col] = adj_net_nat_income_final[col].astype(float)
# Out:
# C:\Users\Office.PHS\AppData\Local\Temp\ipykernel_18792\1513206719.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adj_net_nat_income_final[col] = adj_net_nat_income_final[col].astype(float)

# %%
adj_net_nat_income_final
# Out:
#                                    Country Name Country Code          2002  \
# 1                                       Albania          ALB  3.981527e+09
# 2                                       Algeria          DZA  4.228057e+10
# 5                                        Angola          AGO  9.936398e+09
# 7                                     Argentina          ARG  7.485151e+10
# 8                                       Armenia          ARM  2.062125e+09
# ..                                          ...          ...           ...
# 261                          Sub-Saharan Africa          SSF  3.431770e+11
# 262  Sub-Saharan Africa (excluding high income)          SSA  3.426160e+11
# 263   Sub-Saharan Africa (IDA & IBRD countries)          TSS  3.431770e+11
# 264                         Upper middle income          UMC  3.531560e+12
# 265                                       World          WLD  2.962740e+13
#
# ...

# %%
adj_net_nat_income_final.to_csv('adj_net_national_income_cleaned_full.csv', index=True)

# %%
adj_net_nat_income_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211 entries, 1 to 265
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  211 non-null    object
#  1   Country Code  211 non-null    object
#  2   2002          211 non-null    float64
#  3   2003          211 non-null    float64
#  4   2004          211 non-null    float64
#  5   2005          211 non-null    float64
#  6   2006          211 non-null    float64
#  7   2007          211 non-null    float64
#  8   2008          211 non-null    float64
#  9   2009          211 non-null    float64
#  10  2010          211 non-null    float64
#  11  2011          211 non-null    float64
#  12  2012          211 non-null    float64
#  13  2013          211 non-null    float64
#  14  2014          211 non-null    float64
#  15  2015          211 non-null    float64
#  16  2016          211 non-null    float64
# ...

# %%
# ---------------------------------------------

# %%
gdp_df_droped = gdp_df.drop(columns=['Series Code', 'Series Name', '2020 [YR2020]', '2021 [YR2021]'])

# %%
gdp_df_renamed = gdp_df_droped.rename(columns={
    '2002 [YR2002]' : '2002',
    '2003 [YR2003]' : '2003',
    '2004 [YR2004]' : '2004',
    '2005 [YR2005]' : '2005',
    '2006 [YR2006]' : '2006',
    '2007 [YR2007]' : '2007',
    '2008 [YR2008]' : '2008',
    '2009 [YR2009]' : '2009',
    '2010 [YR2010]' : '2010',
    '2011 [YR2011]' : '2011',
    '2012 [YR2012]' : '2012',
    '2013 [YR2013]' : '2013',
    '2014 [YR2014]' : '2014',
    '2015 [YR2015]' : '2015',
    '2016 [YR2016]' : '2016',
    '2017 [YR2017]' : '2017',
    '2018 [YR2018]' : '2018',
    '2019 [YR2019]' : '2019'   
})

# %%
gdp_df_droped = gdp_df_renamed.replace('..', np.nan)
gdp_df_final = gdp_df_droped.dropna(axis=0)
gdp_df_final
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                              Albania          ALB
# 2                                              Algeria          DZA
# 3                                       American Samoa          ASM
# 4                                              Andorra          AND
# ..                                                 ...          ...
# 261       Least developed countries: UN classification          LDC
# 262  Middle East & North Africa (excluding high inc...          MNA
# 263                                        High income          HIC
# 264                                Low & middle income          LMY
# 265                                Lower middle income          LMC
#
#             2002         2003         2004         2005         2006  \
# 0     3854235264   4539500884   5220823685   6226199249   6971379033
# ...

# %%
for i, col in enumerate(gdp_df_final.columns):
    if i >= 2 and gdp_df_final[col].dtype == 'object':
        gdp_df_final[col] = gdp_df_final[col].astype(float)
# Out:
# C:\Users\Office.PHS\AppData\Local\Temp\ipykernel_18792\3282456162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_df_final[col] = gdp_df_final[col].astype(float)

# %%
gdp_df_final.to_csv('gdp_cleaned_full.csv', index=True)

# %%
gdp_df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 265
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  250 non-null    object
#  1   Country Code  250 non-null    object
#  2   2002          250 non-null    float64
#  3   2003          250 non-null    float64
#  4   2004          250 non-null    float64
#  5   2005          250 non-null    float64
#  6   2006          250 non-null    float64
#  7   2007          250 non-null    float64
#  8   2008          250 non-null    float64
#  9   2009          250 non-null    float64
#  10  2010          250 non-null    float64
#  11  2011          250 non-null    float64
#  12  2012          250 non-null    float64
#  13  2013          250 non-null    float64
#  14  2014          250 non-null    float64
#  15  2015          250 non-null    float64
#  16  2016          250 non-null    float64
# ...

# %%
# ---------------------------------------------

# %%
infl_consum_prices_droped = inflation_consumer_prices_df.drop(columns=['Series Code', 'Series Name', '2020 [YR2020]', '2021 [YR2021]'])

# %%
infl_consum_prices_renamed = infl_consum_prices_droped.rename(columns={
    '2002 [YR2002]' : '2002',
    '2003 [YR2003]' : '2003',
    '2004 [YR2004]' : '2004',
    '2005 [YR2005]' : '2005',
    '2006 [YR2006]' : '2006',
    '2007 [YR2007]' : '2007',
    '2008 [YR2008]' : '2008',
    '2009 [YR2009]' : '2009',
    '2010 [YR2010]' : '2010',
    '2011 [YR2011]' : '2011',
    '2012 [YR2012]' : '2012',
    '2013 [YR2013]' : '2013',
    '2014 [YR2014]' : '2014',
    '2015 [YR2015]' : '2015',
    '2016 [YR2016]' : '2016',
    '2017 [YR2017]' : '2017',
    '2018 [YR2018]' : '2018',
    '2019 [YR2019]' : '2019'  
})

# %%
infl_consum_prices_droped = infl_consum_prices_renamed.replace('..', np.nan)
infl_consum_prices_final = infl_consum_prices_droped.dropna(axis=0)
infl_consum_prices_final
# Out:
#                                    Country Name Country Code         2002  \
# 1                                       Albania          ALB  7.770525834
# 2                                       Algeria          DZA  1.418301923
# 5                                        Angola          AGO  108.8974361
# 6                           Antigua and Barbuda          ATG  2.407658013
# 8                                       Armenia          ARM  1.060049293
# ..                                          ...          ...          ...
# 261                          Sub-Saharan Africa          SSF  4.705791237
# 262  Sub-Saharan Africa (excluding high income)          SSA  5.032822757
# 263   Sub-Saharan Africa (IDA & IBRD countries)          TSS  4.705791237
# 264                         Upper middle income          UMC  5.464426257
# 265                                       World          WLD   2.90799857
#
#             2003         2004         2005         2006         2007  \
# ...

# %%
for i, col in enumerate(infl_consum_prices_final.columns):
    if i >= 2 and infl_consum_prices_final[col].dtype == 'object':
        infl_consum_prices_final[col] = infl_consum_prices_final[col].astype(float)
infl_consum_prices_final
# Out:
# C:\Users\Office.PHS\AppData\Local\Temp\ipykernel_18792\2599513041.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   infl_consum_prices_final[col] = infl_consum_prices_final[col].astype(float)
#                                    Country Name Country Code        2002  \
# 1                                       Albania          ALB    7.770526
# 2                                       Algeria          DZA    1.418302
# 5                                        Angola          AGO  108.897436
# 6                           Antigua and Barbuda          ATG    2.407658
# 8                                       Armenia          ARM    1.060049
# ..                                          ...          ...         ...
# ...

# %%
infl_consum_prices_final.to_csv('inflation_consumer_prices_cleaned_full.csv', index=True)

# %%
infl_consum_prices_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209 entries, 1 to 265
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  209 non-null    object
#  1   Country Code  209 non-null    object
#  2   2002          209 non-null    float64
#  3   2003          209 non-null    float64
#  4   2004          209 non-null    float64
#  5   2005          209 non-null    float64
#  6   2006          209 non-null    float64
#  7   2007          209 non-null    float64
#  8   2008          209 non-null    float64
#  9   2009          209 non-null    float64
#  10  2010          209 non-null    float64
#  11  2011          209 non-null    float64
#  12  2012          209 non-null    float64
#  13  2013          209 non-null    float64
#  14  2014          209 non-null    float64
#  15  2015          209 non-null    float64
#  16  2016          209 non-null    float64
# ...

# %%
# ---------------------------------

# %%
adj_net_nat_income_five_years_df = adj_net_nat_income_final.iloc[:, [0, 1, -5, -4, -3, -2, -1]]

# %%
adj_income_five_years_mean = adj_net_nat_income_five_years_df.assign(NetIncomeMean = ((adj_net_nat_income_five_years_df['2015'] +
                                                adj_net_nat_income_five_years_df['2016'] +
                                                adj_net_nat_income_five_years_df['2017'] +
                                                adj_net_nat_income_five_years_df['2018'] +
                                                adj_net_nat_income_five_years_df['2019'])/5))

adj_income_five_years_mean = adj_income_five_years_mean.drop(columns= ['2015', '2016', '2017', '2018', '2019'])
adj_income_five_years_mean
# Out:
#                                    Country Name Country Code  NetIncomeMean
# 1                                       Albania          ALB   1.094844e+10
# 2                                       Algeria          DZA   1.349942e+11
# 5                                        Angola          AGO   7.549709e+10
# 7                                     Argentina          ARG   4.667820e+11
# 8                                       Armenia          ARM   1.039242e+10
# ..                                          ...          ...            ...
# 261                          Sub-Saharan Africa          SSF   1.382626e+12
# 262  Sub-Saharan Africa (excluding high income)          SSA   1.381402e+12
# 263   Sub-Saharan Africa (IDA & IBRD countries)          TSS   1.382626e+12
# 264                         Upper middle income          UMC   1.674980e+13
# 265                                       World          WLD   6.648098e+13
#
# [211 rows x 3 columns]

# %%
# -------------------------------

# %%
gdp_five_years_df = gdp_df_final.iloc[:, [0, 1, -5, -4, -3, -2, -1]]

# %%
gdp_five_years_mean = gdp_five_years_df.assign(GdpMean = ((gdp_five_years_df['2015'] +
                                                gdp_five_years_df['2016'] +
                                                gdp_five_years_df['2017'] +
                                                gdp_five_years_df['2018'] +
                                                gdp_five_years_df['2019'])/5))

gdp_five_years_mean = gdp_five_years_mean.drop(columns= ['2015', '2016', '2017', '2018', '2019'])
gdp_five_years_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 265
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  250 non-null    object
#  1   Country Code  250 non-null    object
#  2   GdpMean       250 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 7.8+ KB

# %%
gdp_five_years_mean
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                              Albania          ALB
# 2                                              Algeria          DZA
# 3                                       American Samoa          ASM
# 4                                              Andorra          AND
# ..                                                 ...          ...
# 261       Least developed countries: UN classification          LDC
# 262  Middle East & North Africa (excluding high inc...          MNA
# 263                                        High income          HIC
# 264                                Low & middle income          LMY
# 265                                Lower middle income          LMC
#
#           GdpMean
# 0    1.884748e+10
# 1    1.336520e+10
# 2    1.685576e+11
# 3    6.484000e+08
# 4    3.012022e+09
# ..            ...
# ...

# %%
# ---Inflation Consumer Prices Mean for 5 years---

# %%
infl_cons_prices_five_years_df = infl_consum_prices_final.iloc[:, [0, 1, -5, -4, -3, -2, -1]]

# %%
infl_cons_prices_five_years_mean = infl_cons_prices_five_years_df.assign(InflMean = ((gdp_five_years_df['2015'] +
                                                infl_cons_prices_five_years_df['2016'] +
                                                infl_cons_prices_five_years_df['2017'] +
                                                infl_cons_prices_five_years_df['2018'] +
                                                infl_cons_prices_five_years_df['2019'])/5))

infl_cons_prices_five_years_mean = infl_cons_prices_five_years_mean.drop(columns= ['2015', '2016', '2017', '2018', '2019'])
infl_cons_prices_five_years_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209 entries, 1 to 265
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  209 non-null    object
#  1   Country Code  209 non-null    object
#  2   InflMean      207 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 14.6+ KB

# %%
infl_cons_prices_five_years_mean
# Out:
#                                    Country Name Country Code      InflMean
# 1                                       Albania          ALB  2.277370e+09
# 2                                       Algeria          DZA  3.319580e+10
# 5                                        Angola          AGO  1.744386e+10
# 6                           Antigua and Barbuda          ATG  2.673385e+08
# 8                                       Armenia          ARM  2.110668e+09
# ..                                          ...          ...           ...
# 261                          Sub-Saharan Africa          SSF  1.901190e+11
# 262  Sub-Saharan Africa (excluding high income)          SSA  2.878140e+11
# 263   Sub-Saharan Africa (IDA & IBRD countries)          TSS  9.649280e+12
# 264                         Upper middle income          UMC  5.336360e+12
# 265                                       World          WLD  1.309204e+12
#
# [209 rows x 3 columns]

# %%
combined_df = pd.merge(adj_income_five_years_mean, gdp_five_years_mean, how='outer', on='Country Name')
combined_df.tail(50)
# Out:
#                                    Country Name Country Code_x  NetIncomeMean  \
# 200                 Pacific island small states            PSS   8.819213e+09
# 201                   Post-demographic dividend            PST   3.982386e+13
# 202                    Pre-demographic dividend            PRE   1.060726e+12
# 203                                Small states            SST   3.810866e+11
# 204                                  South Asia            SAS   2.842208e+12
# 205                     South Asia (IDA & IBRD)            TSA   2.842208e+12
# 206                          Sub-Saharan Africa            SSF   1.382626e+12
# 207  Sub-Saharan Africa (excluding high income)            SSA   1.381402e+12
# 208   Sub-Saharan Africa (IDA & IBRD countries)            TSS   1.382626e+12
# 209                         Upper middle income            UMC   1.674980e+13
# 210                                       World            WLD   6.648098e+13
# ...

# %%
combined_df = pd.merge(combined_df, infl_cons_prices_five_years_mean, how='outer', on='Country Name')
combined_df.tail()
# Out:
#               Country Name Country Code_x  NetIncomeMean Country Code_y  \
# 246                 Tuvalu            NaN            NaN            TUV
# 247         United Kingdom            NaN            NaN            GBR
# 248  Virgin Islands (U.S.)            NaN            NaN            VIR
# 249     West Bank and Gaza            NaN            NaN            PSE
# 250                Curacao            NaN            NaN            NaN
#
#           GdpMean Country Code      InflMean
# 246  4.514005e+07          NaN           NaN
# 247  2.810626e+12          GBR  5.869720e+11
# 248  3.858800e+09          NaN           NaN
# 249  1.578318e+10          PSE  2.794480e+09
# 250           NaN          CUW           NaN

# %%
combined_df = combined_df.drop(columns=['Country Code_x', 'Country Code_y'])
combined_df.tail()
# Out:
#               Country Name  NetIncomeMean       GdpMean Country Code  \
# 246                 Tuvalu            NaN  4.514005e+07          NaN
# 247         United Kingdom            NaN  2.810626e+12          GBR
# 248  Virgin Islands (U.S.)            NaN  3.858800e+09          NaN
# 249     West Bank and Gaza            NaN  1.578318e+10          PSE
# 250                Curacao            NaN           NaN          CUW
#
#          InflMean
# 246           NaN
# 247  5.869720e+11
# 248           NaN
# 249  2.794480e+09
# 250           NaN

# %%
combined_df = combined_df[['Country Name', 'Country Code', 'NetIncomeMean', 'GdpMean', 'InflMean']]
combined_df.tail()
# Out:
#               Country Name Country Code  NetIncomeMean       GdpMean  \
# 246                 Tuvalu          NaN            NaN  4.514005e+07
# 247         United Kingdom          GBR            NaN  2.810626e+12
# 248  Virgin Islands (U.S.)          NaN            NaN  3.858800e+09
# 249     West Bank and Gaza          PSE            NaN  1.578318e+10
# 250                Curacao          CUW            NaN           NaN
#
#          InflMean
# 246           NaN
# 247  5.869720e+11
# 248           NaN
# 249  2.794480e+09
# 250           NaN

# %%
# combined_df.describe()

# %%
regions_csv = pd.read_csv('Resources/regions.csv')
regions_df = pd.DataFrame(regions_csv)

regions_df = regions_df.rename(columns={"Regions":"Country Name"})
regions_df.head()
# Out:
#                      Country Name
# 0     Africa Eastern and Southern
# 1      Africa Western and Central
# 2                      Arab World
# 3          Caribbean small states
# 4  Central Europe and the Baltics

# %%
combined_df = combined_df[combined_df['Country Name'].isin(regions_df['Country Name'])==False]
combined_df.tail()

combined_df2 = combined_df.copy()
combined_df2 = combined_df2.replace('NaN', np.nan)
combined_df2 = combined_df2.dropna()
combined_df2.count()
# Out:
# Country Name     145
# Country Code     145
# NetIncomeMean    145
# GdpMean          145
# InflMean         145
# dtype: int64

# %%
combined_df2.to_csv('Resources/combined_df2.csv', index=True)

# %%
combined_df2.describe()
# summary_df = combined_df.agg(['mean', 'median', 'var', 'std', 'sem'])
# summary_df
# pd.options.display.float_format = '{:.2f}'.format
# Out:
#        NetIncomeMean       GdpMean      InflMean
# count   1.450000e+02  1.450000e+02  1.450000e+02
# mean    4.236716e+11  5.190636e+11  9.517436e+10
# std     1.664546e+12  2.011520e+12  3.675032e+11
# min     3.837820e+08  3.658708e+08  6.329798e+07
# 25%     1.043481e+10  1.269923e+10  2.323978e+09
# 50%     4.598924e+10  5.372276e+10  9.881314e+09
# 75%     2.315558e+11  2.900674e+11  5.411120e+10
# max     1.684692e+13  1.965850e+13  3.641200e+12

# %%
gdp_sorted = combined_df2.sort_values('GdpMean', ascending=False)
#gdp_sorted = pd.DataFrame({'NetIncomeMean': np.random.randn(10)*1e13})
#gdp_sorted.style.format("{:.5f}")
pd.options.display.float_format = '{:.2f}'.format
gdp_sorted.head()
# Out:
#       Country Name Country Code     NetIncomeMean           GdpMean  \
# 156  United States          USA 16846920000000.00 19658500000000.00
# 32           China          CHN  9442286000000.00 12556000000000.00
# 75           Japan          JPN  3849524000000.00  4908122000000.00
# 58         Germany          DEU  3108428000000.00  3676192000000.00
# 54          France          FRA  2188756000000.00  2605426000000.00
#
#             InflMean
# 156 3641200000001.53
# 32  2212320000001.71
# 75   888986000000.36
# 58   671518000001.04
# 54   487838000000.83

# %%
print(f"The mean GDP of all countrires is: {gdp_sorted['GdpMean']}")
#print(f"The standard deviation of all countries GDP is: {['GdpMean']}")

plt.hist(gdp_sorted['GdpMean'])
plt.xlabel("GDP")
plt.ylabel("Number of Countries")
plt.ticklabel_format(useMathText=True)

plt.show()
# Out:
# The mean GDP of all countrires is: 156   19658500000000.00
# 32    12556000000000.00
# 75     4908122000000.00
# 58     3676192000000.00
# 54     2605426000000.00
#              ...
# 159        848617108.72
# 141        848590992.60
# 44         560965185.18
# 149        463777314.54
# 99         365870840.00
# Name: GdpMean, Length: 145, dtype: float64

# %%
plt.scatter(combined_df2.iloc[:,3],combined_df2.iloc[:,4])
plt.xlabel('GPD')
plt.ylabel('Inflation')
plt.ticklabel_format(useMathText=True)
plt.xlim(0)
plt.ylim(0)
plt.show()

# %%
def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.ticklabel_format(useMathText=True)
    plt.xlim(0)
    plt.ylim(0)
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    plt.show()

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression

xlbl = "NetIncomeMean"
ylbl = "Inflation"
lblpos = (6846920000000, 1000000000000)
plotLinearRegression(combined_df2['NetIncomeMean'],combined_df2['InflMean'],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.9991207122033555

# %%
xlbl = "NetIncomeMean"
ylbl = "GdpMean"
lblpos = (6846920000000, 5000000000000)
plotLinearRegression(combined_df2['NetIncomeMean'],combined_df2['GdpMean'],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.9983196355370841
